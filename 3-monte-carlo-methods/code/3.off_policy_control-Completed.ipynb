# %% [markdown]
# ## Import the necessary software libraries:

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt

from envs import Maze
from utils import plot_policy, plot_action_values, test_agent

# %% [markdown]
# ## Initialize the environment

# %%
env = Maze()

# %%
frame = env.render(mode='rgb_array')
plt.figure(figsize=(6, 6))
plt.axis('off')
plt.imshow(frame)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14076\4216119468.py in <module>
#       1 env.reset()
# ----> 2 frame = env.render()
#
# D:\Dev\tools\envs\tf\lib\site-packages\gym\core.py in render(self, *args, **kwargs)
#      56             )
#      57
# ---> 58         return render_func(self, *args, **kwargs)
#      59
#      60     return render
#
# D:\Dev\Learning\AI Mastery\Reinforcement Learning\3. Monte Carlo Prediction\code\envs.py in render(self, mode)
#     121
#     122         if self.viewer is None:
# --> 123             from gym.envs.classic_control import rendering
#     124             # First time the environment is rendered.
#     125             self.viewer = rendering.Viewer(screen_size, screen_size)
#
# ImportError: cannot import name 'rendering' from 'gym.envs.classic_control' (D:\Dev\tools\envs\tf\lib\site-packages\gym\envs\classic_control\__init__.py)

# %%
print(f"Observation space shape: {env.observation_space.nvec}")
print(f"Number of actions: {env.action_space.n}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9356\400520004.py in <module>
# ----> 1 print(f"Observation space shape: {env.observation_space.nvec}")
#       2 print(f"Number of actions: {env.action_space.n}")
#
# NameError: name 'env' is not defined

# %% [markdown]
# ## Define value table $Q(s, a)$

# %% [markdown]
# #### Create the $Q(s, a)$ table

# %%
action_values = np.full((5,5,4), -100)
action_values[4,4,:] = 0.

# %% [markdown]
# #### Plot $Q(s, a)$

# %%
plot_action_values(action_values)

# %% [markdown]
# ## Define the target policy $\pi(s)$

# %% [markdown]
# #### Create the policy $\pi(s)$

# %%
def target_policy(state):
    av = action_values[state]
    return np.random.choice(np.flatnonzero(av == av.max()))

# %% [markdown]
# #### Test the policy with state (0, 0)

# %%
action = target_policy((0,0))
print(f"Action taken in state (0,0): {action}")
# Out:
# Action taken in state (0,0): 2

# %% [markdown]
# #### Plot the policy

# %%
import gym

frame = env.render(mode='rgb_array')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18772\210396353.py in <module>
#       1 import gym
#       2
# ----> 3 frame = env.render(mode='rgb_array')
#
# NameError: name 'env' is not defined

# %%
plot_policy(action_values, frame)

# %% [markdown]
# ## Define the exploratory policy $b(s)$

# %% [markdown]
# #### Create the policy $b(s)$

# %%
def exploratory_policy(state, epsilon=0.):
    if np.random.random() < epsilon:
        return np.random.randint(4)
    else:
        av = action_values[state]
        return np.random.choice(np.flatnonzero(av == av.max()))

# %% [markdown]
# #### Test the policy with state (0, 0)

# %%
action = exploratory_policy((0,0))
print(f"Action taken in state (0,0): {action}")
# Out:
# Action taken in state (0,0): 3

# %% [markdown]
# #### Plot the policy

# %%
plot_policy(action_values, frame)

# %% [markdown]
# ## Implement the algorithm
#
# ![Screenshot%202021-02-25%20at%2014.06.04.png](attachment:Screenshot%202021-02-25%20at%2014.06.04.png)
#
# </br>
#
#
#
# <div style="text-align:center">
#     Adapted from Barto & Sutton: "Reinforcement Learning: An Introduction".
# </div>

# %%
def off_policy_mc_control(action_values, target_policy, exploratory_policy, episodes, gamma=0.99, epsilon=0.2):
    
    for episode in range(1, episodes + 1):
        G = 0
        W = 1
        csa = np.zeros((5, 5, 4))
        state = env.reset()
        done = False
        transitions = []
        
        while not done:
#             env.render()
            action = exploratory_policy(state, epsilon)
            next_state, reward, done, _ = env.step(action)
            transitions.append([state, action, reward])
            state = next_state

        for state_t, action_t, reward_t in reversed(transitions):
            G = reward_t + gamma * G
            csa[state_t][action_t] += W
            qsa = action_values[state_t][action_t]
            action_values[state_t][action_t] += (W / csa[state_t][action_t]) * (G - qsa)

            if action_t != target_policy(state_t):
                break

            W = W * 1. / (1 - epsilon + epsilon/4)

# %%
off_policy_mc_control(action_values, target_policy, exploratory_policy, episodes=1000, epsilon=0.3)

# %% [markdown]
# ## Show results

# %% [markdown]
# #### Show resulting value table $Q(s, a)$

# %%
plot_action_values(action_values)

# %% [markdown]
# #### Show resulting policy $\pi(\cdot|s)$

# %%
plot_policy(action_values, frame)

# %% [markdown]
# #### Test the resulting agent

# %%
test_agent(env, target_policy)

# %% [markdown]
# ## Resources

# %% [markdown]
# [[1] Reinforcement Learning: An Introduction. Ch. 5: Monte Carlo methods](https://web.stanford.edu/class/psych209/Readings/SuttonBartoIPRLBook2ndEd.pdf)
